# %%
# !pip install -U numba statsforecast datasetsforecast
# Out:
# Requirement already satisfied: numba in c:\users\iqraimtiaz\.conda\envs\nixtla\lib\site-packages (0.60.0)
# Collecting statsforecast
#   Downloading statsforecast-1.7.6-py3-none-any.whl.metadata (28 kB)
# Collecting datasetsforecast
#   Downloading datasetsforecast-0.0.8-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\iqraimtiaz\.conda\envs\nixtla\lib\site-packages (from numba) (0.43.0)
# Requirement already satisfied: numpy<2.1,>=1.22 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from numba) (1.26.4)
# Collecting cloudpickle (from statsforecast)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting coreforecast>=0.0.12 (from statsforecast)
#   Downloading coreforecast-0.0.12-py3-none-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: pandas>=1.3.5 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from statsforecast) (2.2.2)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from statsforecast) (1.14.0)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\iqraimtiaz\.conda\envs\nixtla\lib\site-packages (from statsforecast) (0.14.2)
# Requirement already satisfied: tqdm in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from statsforecast) (4.66.4)
# Collecting fugue>=0.8.1 (from statsforecast)
#   Downloading fugue-0.9.1-py3-none-any.whl.metadata (18 kB)
# Collecting utilsforecast>=0.1.4 (from statsforecast)
#   Downloading utilsforecast-0.2.3-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: threadpoolctl in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from statsforecast) (3.5.0)
# Requirement already satisfied: aiohttp in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from datasetsforecast) (3.9.5)
# Requirement already satisfied: requests in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from datasetsforecast) (2.32.3)
# Collecting xlrd>=1.0.0 (from datasetsforecast)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting triad>=0.9.7 (from fugue>=0.8.1->statsforecast)
#   Downloading triad-0.9.8-py3-none-any.whl.metadata (6.3 kB)
# Collecting adagio>=0.2.4 (from fugue>=0.8.1->statsforecast)
#   Downloading adagio-0.2.4-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from pandas>=1.3.5->statsforecast) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from pandas>=1.3.5->statsforecast) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from pandas>=1.3.5->statsforecast) (2024.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\iqraimtiaz\.conda\envs\nixtla\lib\site-packages (from statsmodels>=0.13.2->statsforecast) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from statsmodels>=0.13.2->statsforecast) (24.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from aiohttp->datasetsforecast) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from aiohttp->datasetsforecast) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from aiohttp->datasetsforecast) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from aiohttp->datasetsforecast) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from aiohttp->datasetsforecast) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from aiohttp->datasetsforecast) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from requests->datasetsforecast) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from requests->datasetsforecast) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from requests->datasetsforecast) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from requests->datasetsforecast) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from tqdm->statsforecast) (0.4.6)
# Requirement already satisfied: six in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->statsforecast) (1.16.0)
# Requirement already satisfied: pyarrow>=6.0.1 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast) (17.0.0)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\users\iqraimtiaz\appdata\roaming\python\python310\site-packages (from triad>=0.9.7->fugue>=0.8.1->statsforecast) (2024.5.0)
# Collecting fs (from triad>=0.9.7->fugue>=0.8.1->statsforecast)
#   Downloading fs-2.4.16-py2.py3-none-any.whl.metadata (6.3 kB)
# Collecting appdirs~=1.4.3 (from fs->triad>=0.9.7->fugue>=0.8.1->statsforecast)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: setuptools in c:\users\iqraimtiaz\.conda\envs\nixtla\lib\site-packages (from fs->triad>=0.9.7->fugue>=0.8.1->statsforecast) (72.1.0)
# Downloading statsforecast-1.7.6-py3-none-any.whl (134 kB)
# Downloading datasetsforecast-0.0.8-py3-none-any.whl (27 kB)
# Downloading coreforecast-0.0.12-py3-none-win_amd64.whl (101 kB)
# Downloading fugue-0.9.1-py3-none-any.whl (278 kB)
# Downloading utilsforecast-0.2.3-py3-none-any.whl (40 kB)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading adagio-0.2.4-py3-none-any.whl (26 kB)
# Downloading triad-0.9.8-py3-none-any.whl (62 kB)
# Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: appdirs, xlrd, fs, coreforecast, cloudpickle, utilsforecast, triad, adagio, fugue, statsforecast, datasetsforecast
# Successfully installed adagio-0.2.4 appdirs-1.4.4 cloudpickle-3.0.0 coreforecast-0.0.12 datasetsforecast-0.0.8 fs-2.4.16 fugue-0.9.1 statsforecast-1.7.6 triad-0.9.8 utilsforecast-0.2.3 xlrd-2.0.1

# %%
import numpy as np
import pandas as pd

#obtain hierarchical dataset
from datasetsforecast.hierarchical import HierarchicalData

# compute base forecast no coherent
from statsforecast.core import StatsForecast
from statsforecast.models import AutoARIMA, Naive

#obtain hierarchical reconciliation methods and evaluation
from hierarchicalforecast.core import HierarchicalReconciliation
from hierarchicalforecast.evaluation import HierarchicalEvaluation
from hierarchicalforecast.methods import BottomUp, TopDown, MiddleOut


# Load TourismSmall dataset
Y_df, S, tags = HierarchicalData.load('./data', 'TourismSmall')
Y_df['ds'] = pd.to_datetime(Y_df['ds'])

#split train/test sets
Y_test_df  = Y_df.groupby('unique_id').tail(4)
Y_train_df = Y_df.drop(Y_test_df.index)

# Compute base auto-ARIMA predictions
fcst = StatsForecast(df=Y_train_df,
                     models=[AutoARIMA(season_length=4), Naive()],
                     freq='Q', n_jobs=-1)
Y_hat_df = fcst.forecast(h=4)

# Reconcile the base predictions
reconcilers = [
    BottomUp(),
    TopDown(method='forecast_proportions'),
    MiddleOut(middle_level='Country/Purpose/State',
              top_down_method='forecast_proportions')
]
hrec = HierarchicalReconciliation(reconcilers=reconcilers)
Y_rec_df = hrec.reconcile(Y_hat_df=Y_hat_df, Y_df=Y_train_df,
                          S=S, tags=tags)
# Out:
# c:\Users\IqraImtiaz\.conda\envs\nixtla\lib\site-packages\statsforecast\core.py:474: FutureWarning: The `df` argument of the StatsForecast constructor as well as reusing stored dfs from other methods is deprecated and will raise an error in a future version. Please provide the `df` argument to the corresponding method instead, e.g. fit/forecast.
#   warnings.warn(
# c:\Users\IqraImtiaz\.conda\envs\nixtla\lib\site-packages\statsforecast\core.py:474: FutureWarning: The `df` argument of the StatsForecast constructor as well as reusing stored dfs from other methods is deprecated and will raise an error in a future version. Please provide the `df` argument to the corresponding method instead, e.g. fit/forecast.
#   warnings.warn(
# c:\Users\IqraImtiaz\.conda\envs\nixtla\lib\site-packages\utilsforecast\processing.py:384: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   freq = pd.tseries.frequencies.to_offset(freq)
# c:\Users\IqraImtiaz\.conda\envs\nixtla\lib\site-packages\utilsforecast\processing.py:438: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   freq = pd.tseries.frequencies.to_offset(freq)
# c:\Users\IqraImtiaz\.conda\envs\nixtla\lib\site-packages\statsforecast\core.py:492: FutureWarning: In a future version the predictions will have the id as a column. You can set the `NIXTLA_ID_AS_COL` environment variable to adopt the new behavior and to suppress this warning.
#   warnings.warn(

# %%
tags
# Out:
# {'Country': array(['total'], dtype=object),
#  'Country/Purpose': array(['hol', 'vfr', 'bus', 'oth'], dtype=object),
#  'Country/Purpose/State': array(['nsw-hol', 'vic-hol', 'qld-hol', 'sa-hol', 'wa-hol', 'tas-hol',
#         'nt-hol', 'nsw-vfr', 'vic-vfr', 'qld-vfr', 'sa-vfr', 'wa-vfr',
#         'tas-vfr', 'nt-vfr', 'nsw-bus', 'vic-bus', 'qld-bus', 'sa-bus',
#         'wa-bus', 'tas-bus', 'nt-bus', 'nsw-oth', 'vic-oth', 'qld-oth',
#         'sa-oth', 'wa-oth', 'tas-oth', 'nt-oth'], dtype=object),
#  'Country/Purpose/State/CityNonCity': array(['nsw-hol-city', 'nsw-hol-noncity', 'vic-hol-city',
#         'vic-hol-noncity', 'qld-hol-city', 'qld-hol-noncity',
#         'sa-hol-city', 'sa-hol-noncity', 'wa-hol-city', 'wa-hol-noncity',
#         'tas-hol-city', 'tas-hol-noncity', 'nt-hol-city', 'nt-hol-noncity',
#         'nsw-vfr-city', 'nsw-vfr-noncity', 'vic-vfr-city',
#         'vic-vfr-noncity', 'qld-vfr-city', 'qld-vfr-noncity',
#         'sa-vfr-city', 'sa-vfr-noncity', 'wa-vfr-city', 'wa-vfr-noncity',
#         'tas-vfr-city', 'tas-vfr-noncity', 'nt-vfr-city', 'nt-vfr-noncity',
#         'nsw-bus-city', 'nsw-bus-noncity', 'vic-bus-city',
#         'vic-bus-noncity', 'qld-bus-city', 'qld-bus-noncity',
#         'sa-bus-city', 'sa-bus-noncity', 'wa-bus-city', 'wa-bus-noncity',
#         'tas-bus-city', 'tas-bus-noncity', 'nt-bus-city', 'nt-bus-noncity',
#         'nsw-oth-city', 'nsw-oth-noncity', 'vic-oth-city',
#         'vic-oth-noncity', 'qld-oth-city', 'qld-oth-noncity',
#         'sa-oth-city', 'sa-oth-noncity', 'wa-oth-city', 'wa-oth-noncity',
#         'tas-oth-city', 'tas-oth-noncity', 'nt-oth-city', 'nt-oth-noncity'],
#        dtype=object)}

# %%
S
# Out:
#                  nsw-hol-city  nsw-hol-noncity  vic-hol-city  vic-hol-noncity  \
# total                     1.0              1.0           1.0              1.0
# hol                       1.0              1.0           1.0              1.0
# vfr                       0.0              0.0           0.0              0.0
# bus                       0.0              0.0           0.0              0.0
# oth                       0.0              0.0           0.0              0.0
# ...                       ...              ...           ...              ...
# wa-oth-noncity            0.0              0.0           0.0              0.0
# tas-oth-city              0.0              0.0           0.0              0.0
# tas-oth-noncity           0.0              0.0           0.0              0.0
# nt-oth-city               0.0              0.0           0.0              0.0
# nt-oth-noncity            0.0              0.0           0.0              0.0
#
#                  qld-hol-city  qld-hol-noncity  sa-hol-city  sa-hol-noncity  \
# total                     1.0              1.0          1.0             1.0
# hol                       1.0              1.0          1.0             1.0
# vfr                       0.0              0.0          0.0             0.0
# bus                       0.0              0.0          0.0             0.0
# oth                       0.0              0.0          0.0             0.0
# ...                       ...              ...          ...             ...
# wa-oth-noncity            0.0              0.0          0.0             0.0
# tas-oth-city              0.0              0.0          0.0             0.0
# tas-oth-noncity           0.0              0.0          0.0             0.0
# nt-oth-city               0.0              0.0          0.0             0.0
# nt-oth-noncity            0.0              0.0          0.0             0.0
#
#                  wa-hol-city  wa-hol-noncity  ...  qld-oth-city  \
# total                    1.0             1.0  ...           1.0
# hol                      1.0             1.0  ...           0.0
# vfr                      0.0             0.0  ...           0.0
# bus                      0.0             0.0  ...           0.0
# oth                      0.0             0.0  ...           1.0
# ...                      ...             ...  ...           ...
# wa-oth-noncity           0.0             0.0  ...           0.0
# tas-oth-city             0.0             0.0  ...           0.0
# tas-oth-noncity          0.0             0.0  ...           0.0
# nt-oth-city              0.0             0.0  ...           0.0
# nt-oth-noncity           0.0             0.0  ...           0.0
#
#                  qld-oth-noncity  sa-oth-city  sa-oth-noncity  wa-oth-city  \
# total                        1.0          1.0             1.0          1.0
# hol                          0.0          0.0             0.0          0.0
# vfr                          0.0          0.0             0.0          0.0
# bus                          0.0          0.0             0.0          0.0
# oth                          1.0          1.0             1.0          1.0
# ...                          ...          ...             ...          ...
# wa-oth-noncity               0.0          0.0             0.0          0.0
# tas-oth-city                 0.0          0.0             0.0          0.0
# tas-oth-noncity              0.0          0.0             0.0          0.0
# nt-oth-city                  0.0          0.0             0.0          0.0
# nt-oth-noncity               0.0          0.0             0.0          0.0
#
#                  wa-oth-noncity  tas-oth-city  tas-oth-noncity  nt-oth-city  \
# total                       1.0           1.0              1.0          1.0
# hol                         0.0           0.0              0.0          0.0
# vfr                         0.0           0.0              0.0          0.0
# bus                         0.0           0.0              0.0          0.0
# oth                         1.0           1.0              1.0          1.0
# ...                         ...           ...              ...          ...
# wa-oth-noncity              1.0           0.0              0.0          0.0
# tas-oth-city                0.0           1.0              0.0          0.0
# tas-oth-noncity             0.0           0.0              1.0          0.0
# nt-oth-city                 0.0           0.0              0.0          1.0
# nt-oth-noncity              0.0           0.0              0.0          0.0
#
#                  nt-oth-noncity
# total                       1.0
# hol                         0.0
# vfr                         0.0
# bus                         0.0
# oth                         1.0
# ...                         ...
# wa-oth-noncity              0.0
# tas-oth-city                0.0
# tas-oth-noncity             0.0
# nt-oth-city                 0.0
# nt-oth-noncity              1.0
#
# [89 rows x 56 columns]

# %%
def mse(y, y_hat):
    return np.mean((y-y_hat)**2)

evaluator = HierarchicalEvaluation(evaluators=[mse])
evaluator.evaluate(Y_hat_df=Y_rec_df, Y_test_df=Y_test_df.set_index('unique_id'),
                   tags=tags, benchmark='Naive')
# Out:
#                                              AutoARIMA Naive  \
# level                             metric
# Overall                           mse-scaled  0.177661   1.0
# Country                           mse-scaled  0.132836   1.0
# Country/Purpose                   mse-scaled  0.193802   1.0
# Country/Purpose/State             mse-scaled  0.193535   1.0
# Country/Purpose/State/CityNonCity mse-scaled  0.284868   1.0
#
#                                              AutoARIMA/BottomUp  \
# level                             metric
# Overall                           mse-scaled           0.135228
# Country                           mse-scaled           0.100193
# Country/Purpose                   mse-scaled           0.112566
# Country/Purpose/State             mse-scaled           0.219211
# Country/Purpose/State/CityNonCity mse-scaled           0.284868
#
#                                              Naive/BottomUp  \
# level                             metric
# Overall                           mse-scaled            1.0
# Country                           mse-scaled            1.0
# Country/Purpose                   mse-scaled            1.0
# Country/Purpose/State             mse-scaled            1.0
# Country/Purpose/State/CityNonCity mse-scaled            1.0
#
#                                              AutoARIMA/TopDown_method-forecast_proportions  \
# level                             metric
# Overall                           mse-scaled                                      0.150037
# Country                           mse-scaled                                      0.132836
# Country/Purpose                   mse-scaled                                       0.11976
# Country/Purpose/State             mse-scaled                                      0.213761
# Country/Purpose/State/CityNonCity mse-scaled                                      0.281624
#
#                                              Naive/TopDown_method-forecast_proportions  \
# level                             metric
# Overall                           mse-scaled                                       1.0
# Country                           mse-scaled                                       1.0
# Country/Purpose                   mse-scaled                                       1.0
# Country/Purpose/State             mse-scaled                                       1.0
# Country/Purpose/State/CityNonCity mse-scaled                                       1.0
#
#                                              AutoARIMA/MiddleOut_middle_level-Country/Purpose/State_top_down_method-forecast_proportions  \
# level                             metric
# Overall                           mse-scaled                                           0.135045
# Country                           mse-scaled                                           0.131054
# Country/Purpose                   mse-scaled                                              0.092
# Country/Purpose/State             mse-scaled                                           0.193535
# Country/Purpose/State/CityNonCity mse-scaled                                           0.272969
#
#                                              Naive/MiddleOut_middle_level-Country/Purpose/State_top_down_method-forecast_proportions
# level                             metric
# Overall                           mse-scaled                                                1.0
# Country                           mse-scaled                                                1.0
# Country/Purpose                   mse-scaled                                                1.0
# Country/Purpose/State             mse-scaled                                                1.0
# Country/Purpose/State/CityNonCity mse-scaled                                                1.0
